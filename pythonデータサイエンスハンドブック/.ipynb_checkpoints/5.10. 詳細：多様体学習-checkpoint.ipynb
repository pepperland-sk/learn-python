# %% [markdown]
# `多様体学習` 教師なし学習の一種であり、高次元空間に埋め込まれた非線形の多様体を探す

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %% [markdown]
# ## 5.10.1 多様体学習：HELLO

# %%
def make_hello(N=1000, rseed=42):
    # テキスト「HELLO」をプロットし、PNGとして保存する
    fig, ax = plt.subplots(figsize=(4, 1))
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1)
    ax.axis('off')
    ax.text(0.5, 0.4, 'HELLO', va='center', ha='center', weight='bold', size=85)
    fig.savefig('hello.png')
    plt.close(fig)
    
    # PNGをオープンし、そこからランダムに点を描画する
    from matplotlib.image import imread
    data = imread('hello.png')[::-1, :, 0].T
    rng = np.random.RandomState(rseed)
    X = rng.rand(4 * N, 2)
    i, j = (X * data.shape).astype(int).T
    mask = (data[i, j] < 1)
    X = X[mask]
    X[:, 0] *= (data.shape[0] / data.shape[1])
    X = X[:N]
    return X[np.argsort(X[:, 0])]

# %%
X = make_hello(1000)
colorize = dict(c=X[:, 0], cmap=plt.cm.get_cmap('rainbow', 5))
plt.scatter(X[:, 0], X[:, 1], **colorize)
plt.axis('equal');

# %% [markdown]
# ## 5.10.2 多次元尺度構成法（MDS）

# %%
def rotate(X, angle):
    theta = np.deg2rad(angle)
    R = [[np.cos(theta), np.sin(theta)], [-np.sin(theta), np.cos(theta)]]
    return np.dot(X, R)

X2 = rotate(X, 20) + 5
plt.scatter(X2[:, 0], X2[:, 1], **colorize)
plt.axis('equal');

# %% [markdown]
# 回転行列によりデータを回転させてもデータそのものは変わらないため、x,yの値が必ずしもデータの関係にとって本質的でないことがわかる。

# %%
#距離行列：要素i, jがポイントiとポイントjの間の距離を含むようなN×N配列
from sklearn.metrics import pairwise_distances
D = pairwise_distances(X)
D.shape
# Out:
# (1000, 1000)

# %%
#ポイント間距離の可視化
plt.imshow(D, zorder=2, cmap='Blues', interpolation='nearest')
plt.colorbar();

# %%
#回転させたデータの距離行列を確認
D2 = pairwise_distances(X2)
np.allclose(D, D2)
# Out:
# True

# %%
#距離行列から復元されたMDS埋め込み
from sklearn.manifold import MDS
model = MDS(n_components=2, dissimilarity='precomputed', random_state=1)
out = model.fit_transform(D)
plt.scatter(out[:, 0], out[:, 1], **colorize)
plt.axis('equal');

# %% [markdown]
# MDSアルゴリズムは、データポイント間の関係を記述するN×Nの距離行列のみを使用して、データの2次元座標表現の可能性の1つを復元する。

# %% [markdown]
# ## 5.10.3 多様体学習としてのMDS

# %%
#2次元平面上のデータを3次元に投影
def random_projection(X, dimension=3, rseed=42):
    assert dimension >= X.shape[1]
    rng = np.random.RandomState(rseed)
    C = rng.randn(dimension, dimension)
    e, V = np.linalg.eigh(np.dot(C, C.T))
    return np.dot(X, V[:X.shape[1]])

X3 = random_projection(X, 3)
X3.shape
# Out:
# (1000, 3)

# %%
from mpl_toolkits import mplot3d
ax = plt.axes(projection='3d')
ax.scatter3D(X3[:, 0], X3[:, 1], X3[:, 2], **colorize)
ax.view_init(azim=70, elev=50)

# %%
#距離行列の最適な2次元埋め込みを决定
model = MDS(n_components=2, random_state=1)
out3 = model.fit_transform(X3)
plt.scatter(out3[:, 0], out3[:, 1], **colorize)
plt.axis('equal');

# %% [markdown]
# - 高次元の埋め込みデータを与えると、データ内の特定の関係を保持する低次元のデータ表現を求める。
# - MDSの場合、保存される量はすべてのポイント間の距離

# %% [markdown]
# ## 5.10.4 非線形埋め込み：MDSがうまくいかない場合

# %%
#入力を3次元空間内で「S」の字に曲げる
def make_hello_s_curve(X):
    t = (X[:, 0] - 2) * 0.75 * np.pi
    x = np.sin(t)
    y = X[:, 1]
    z = np.sign(t) * (np.cos(t) - 1)
    return np.vstack((x, y, z)).T

XS = make_hello_s_curve(X)

# %%
#3次元に、非線形に埋め込まれたデータ
from mpl_toolkits import mplot3d
ax = plt.axes(projection='3d')
ax.scatter3D(XS[:, 0], XS[:, 1], XS[:, 2],
             **colorize);

# %%
from sklearn.manifold import MDS
model = MDS(n_components=2, random_state=2)
outS = model.fit_transform(XS)
plt.scatter(outS[:, 0], outS[:, 1], **colorize)
plt.axis('equal');

# %% [markdown]
# 元のy軸情報を破棄している

# %% [markdown]
# ## 5.10.5 非線形多様体：局所線形埋め込み（LLE）

# %% [markdown]
# `局所線形埋め込み（LLE：Locally Liner Embedding）`：すべての距離を保存するのではなく、`近傍点`間の距離のみを保存する

# %%
#局所線形埋め込みによる非線形に埋め込まれた入力からのデータ復元
from sklearn.manifold import LocallyLinearEmbedding
model = LocallyLinearEmbedding(n_neighbors=100, n_components=2, method='modified', eigen_solver='dense')
out = model.fit_transform(XS)
fig, ax = plt.subplots()
ax.scatter(out[:, 0], out[:, 1], **colorize)
ax.set_ylim(0.15, -0.15);

# %% [markdown]
# ## 多様体学習に対する考察

# %% [markdown]
# <PCAと比較し劣っている点>
# - 欠損データを処理するための良いフレームワークがない
# - データにノイズが存在すると多様体を「短絡」させ、埋め込みを大幅に変化させる
# - 一般的な埋込結果は選択された近傍の数に大きく依存するが、最適な数の近傍を選択するための一般的な定量的方法がない
# - 最適な出力次元数の特定が困難
# - 埋め込まれた次元の意味は必ずしも明確ではない
# - 多様体学習の計算コストは$O[N^2]$または$O[N^3]$

# %% [markdown]
# <唯一の利点>
# - データの非線形の関係を保てる

# %% [markdown]
# ## 5.10.7 事例：顔画像へのIsomap適用

# %%
from sklearn.datasets import fetch_lfw_people
faces = fetch_lfw_people(min_faces_per_person=30)
faces.data.shape
# Out:
# (1952, 2914)

# %%
fig, ax = plt.subplots(4, 8, subplot_kw=dict(xticks=[], yticks=[]))
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[i], cmap='gray')

# %%
#低次元埋め込みをプロット
from sklearn.decomposition import PCA
model = PCA(100, svd_solver='randomized').fit(faces.data)
plt.plot(np.cumsum(model.explained_variance_ratio_))
plt.xlabel('n components')
plt.ylabel('cumulative variance');

# %%
#非線形埋め込み(Isomap)を事項
from sklearn.manifold import Isomap
model = Isomap(n_components=2)
proj = model.fit_transform(faces.data)
proj.shape
# Out:
# (1952, 2)

# %%
#投影の位置に画像のサムネイルを出力する関数を定義する
from matplotlib import offsetbox

def plot_components(data, model, images=None, ax=None,
                    thumb_frac=0.05, cmap='gray'):
    ax = ax or plt.gca()
    
    proj = model.fit_transform(data)
    ax.plot(proj[:, 0], proj[:, 1], '.k')
    
    if images is not None:
        min_dist_2 = (thumb_frac * max(proj.max(0) - proj.min(0))) ** 2
        shown_images = np.array([2 * proj.max(0)])
        for i in range(data.shape[0]):
            dist = np.sum((proj[i] - shown_images) ** 2, 1)
            if np.min(dist) < min_dist_2:
                # don't show points that are too close
                continue
            shown_images = np.vstack([shown_images, proj[i]])
            imagebox = offsetbox.AnnotationBbox(
                offsetbox.OffsetImage(images[i], cmap=cmap),
                                      proj[i])
            ax.add_artist(imagebox)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_components(faces.data,
                model=Isomap(n_components=2),
                images=faces.images[:, ::2, ::2])

# %% [markdown]
# ## 5.10.8 事例：手書き数字構造の可視化

# %%
from sklearn.datasets import fetch_mldata
mnist = fetch_mldata('MNIST original')
mnist.data.shape
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-26-ceec0649e119> in <module>()
#       1 from sklearn.datasets import fetch_mldata
# ----> 2 mnist = fetch_mldata('MNIST original')
#       3 mnist.data.shape
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/datasets/mldata.py in fetch_mldata(dataname, target_name, data_name, transpose_data, data_home)
#     152         urlname = MLDATA_BASE_URL % quote(dataname)
#     153         try:
# --> 154             mldata_url = urlopen(urlname)
#     155         except HTTPError as e:
#     156             if e.code == 404:
#
# ~/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ...

# %%
fig, ax = plt.subplots(6, 8, subplot_kw=dict(xticks=[], yticks=[]))
for i, axi in enumerate(ax.flat):
    axi.imshow(mnist.data[1250 * i].reshape(28, 28), cmap='gray_r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d4b9b4b43d9d> in <module>()
#       1 fig, ax = plt.subplots(6, 8, subplot_kw=dict(xticks=[], yticks=[]))
#       2 for i, axi in enumerate(ax.flat):
# ----> 3     axi.imshow(mnist.data[1250 * i].reshape(28, 28), cmap='gray_r')
#
# NameError: name 'mnist' is not defined
